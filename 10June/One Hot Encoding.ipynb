# %%
import pandas as pd

# %%
df = pd.read_csv('pr.csv')
df.head(1)
# Out:
#    area  locality    price
# 0    608  station  2092654

# %%
#dummy
# one hot encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      14 non-null     int64
#  1   locality  14 non-null     object
#  2   price     14 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 468.0+ bytes

# %%
dummy = pd.get_dummies(df.locality)
dummy
# Out:
#     center     old  station
# 0     False  False     True
# 1      True  False    False
# 2     False   True    False
# 3     False  False     True
# 4      True  False    False
# 5      True  False    False
# 6     False   True    False
# 7      True  False    False
# 8     False  False     True
# 9     False   True    False
# 10     True  False    False
# 11    False  False     True
# 12    False   True    False
# 13    False  False     True

# %%
dummy.to_csv('dummy.csv')

# %%
merge = pd.concat([df,dummy], axis = 'columns')
merge
# Out:
#     area  locality    price  center     old  station
# 0     608  station  2092654    False  False     True
# 1     856  center   1753129     True  False    False
# 2     976      old  1445491    False   True    False
# 3    1079  station   665163    False  False     True
# 4     627  center   1712205     True  False    False
# 5     855  center   2395024     True  False    False
# 6    1182      old  1131080    False   True    False
# 7     888  center   1125704     True  False    False
# 8     627  station   337824    False  False     True
# 9    1198      old   740417    False   True    False
# 10   1159  center   1285377     True  False    False
# 11    685  station  1439104    False  False     True
# 12    823      old  1810898    False   True    False
# 13   1169  station  1966157    False  False     True

# %%
merge.drop(['locality'],axis=1)
# Out:
#     area     price  center     old  station
# 0     608  2092654    False  False     True
# 1     856  1753129     True  False    False
# 2     976  1445491    False   True    False
# 3    1079   665163    False  False     True
# 4     627  1712205     True  False    False
# 5     855  2395024     True  False    False
# 6    1182  1131080    False   True    False
# 7     888  1125704     True  False    False
# 8     627   337824    False  False     True
# 9    1198   740417    False   True    False
# 10   1159  1285377     True  False    False
# 11    685  1439104    False  False     True
# 12    823  1810898    False   True    False
# 13   1169  1966157    False  False     True

# %%
# a.replace([False,True] , [0,1] , inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a = df

# %%
a.locality = le.fit_transform(a.locality)

# %%
a
# Out:
#     area   locality    price
# 0     608         2  2092654
# 1     856         0  1753129
# 2     976         1  1445491
# 3    1079         2   665163
# 4     627         0  1712205
# 5     855         0  2395024
# 6    1182         1  1131080
# 7     888         0  1125704
# 8     627         2   337824
# 9    1198         1   740417
# 10   1159         0  1285377
# 11    685         2  1439104
# 12    823         1  1810898
# 13   1169         2  1966157

# %%
from sklearn.linear_model import  LinearRegression

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %%
model.fit(a.drop('price' ,axis=1),a.price)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 2209722.230313422

# %%
model.coef_
# Out:
# array([   -656.43323957, -191298.30129867])

# %%
model.predict([[1500,2]])
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([842475.76836093])
