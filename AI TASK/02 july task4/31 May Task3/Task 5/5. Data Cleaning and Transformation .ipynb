# %% [markdown]
# ### Scenario:
# ### You have a dataset on customer purchases with the following issues:
# ### Missing values in the "price" column.
#
# ### Inconsistent data types (prices might be strings with a currency symbol).
# ### Inconsistent product names (typos or capitalization).
#
# ### Goal: Clean and transform the data using pandas functions.

# %%
# install and import library 
# pip install pandas
import pandas as pd

# %%
# Load the dataset from a CSV file
df = pd.read_csv('car_sales.csv')

# %%
# dimension of dataset
df.shape
# Out:
# (20, 7)

# %%
# top 5 rows
df.head()
# Out:
#          Date      Salesperson   Customer Name Car Make  Car Model  Car Year  \
# 0  01-08-2022  Monica Moore MD     Mary Butler   Nissan     Altima      2018
# 1  15-03-2023     Roberto Rose  Richard Pierce   Nissan      F-150      2016
# 2  29-04-2023     Ashley Ramos    Sandra Moore     Ford      Civic      2016
# 3  04-09-2022   Patrick Harris    Johnny Scott     Ford     Altima      2013
# 4  16-06-2022       Eric Lopez   Vanessa Jones    Honda  Silverado      2022
#
#   Sale Price
# 0      15983
# 1       $238
# 2        NaN
# 3      41937
# 4      20256

# %%
# know data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           20 non-null     object
#  1   Salesperson    20 non-null     object
#  2   Customer Name  20 non-null     object
#  3   Car Make       20 non-null     object
#  4   Car Model      20 non-null     object
#  5   Car Year       20 non-null     int64
#  6   Sale Price     15 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 1.2+ KB

# %%
# count null values
df.isnull().sum()
# Out:
# Date             0
# Salesperson      0
# Customer Name    0
# Car Make         0
# Car Model        0
# Car Year         0
# Sale Price       5
# dtype: int64

# %%
# replace $ sign
df['Sale Price'] = df['Sale Price'].replace({'\$': '', ',': ''}, regex=True)

# %%
df
# Out:
#           Date         Salesperson      Customer Name   Car Make  Car Model  \
# 0   01-08-2022     Monica Moore MD        Mary Butler     Nissan     Altima
# 1   15-03-2023        Roberto Rose     Richard Pierce     Nissan      F-150
# 2   29-04-2023        Ashley Ramos       Sandra Moore       Ford      Civic
# 3   04-09-2022      Patrick Harris       Johnny Scott       Ford     Altima
# 4   16-06-2022          Eric Lopez      Vanessa Jones      Honda  Silverado
# 5   18-12-2022    Terry Perkins MD         John Olsen       Ford     Altima
# 6   12-06-2022        Ashley Brown       Tyler Lawson      Honda      F-150
# 7   20-06-2022       Norma Watkins       Michael Bond       Ford     Altima
# 8   02-09-2022        Scott Parker    Stephanie Smith       Ford    Corolla
# 9   06-04-2023        Andrew Smith  Ashley Moreno DDS       Ford      Civic
# 10  12-03-2023       Harold Nelson       Isaac Patton      Honda  Silverado
# 11  29-01-2023  Richard Richardson        Justin Gray     Toyota  Silverado
# 12  29-05-2022          Mia Acosta       Rebecca Best       Ford     Altima
# 13  12-08-2022       Lisa Campbell      Lisa Anderson     Toyota      F-150
# 14  06-04-2023       Carrie Howard       Rodney Black  Chevrolet     Altima
# 15  21-12-2022     James Velasquez   Natalie Thompson      Honda    Corolla
# 16  12-08-2022      Kristin Holmes       Michael Hill     Nissan     Altima
# 17  23-08-2022         Amy Solomon       Taylor Moore     Nissan  Silverado
# 18  18-10-2022    William Williams      Jordan Taylor     Toyota      Civic
# 19  09-03-2023   Patricia Reynolds      Alison Walker       Ford     Altima
#
#     Car Year Sale Price
# 0       2018      15983
# 1       2016        238
# 2       2016        NaN
# 3       2013      41937
# 4       2022      20256
# 5       2015     147.69
# 6       2013      41397
# 7       2015        NaN
# 8       2021        NaN
# 9       2018      16309
# 10      2021      41259
# 11      2022      48224
# 12      2017      36409
# 13      2011      29628
# 14      2021        NaN
# 15      2016      36607
# 16      2010      39916
# 17      2018      18482
# 18      2013      17158
# 19      2014        NaN

# %%
# fillna 
df['Sale Price'].fillna(0)
# Out:
# 0      15983
# 1        238
# 2          0
# 3      41937
# 4      20256
# 5     147.69
# 6      41397
# 7          0
# 8          0
# 9      16309
# 10     41259
# 11     48224
# 12     36409
# 13     29628
# 14         0
# 15     36607
# 16     39916
# 17     18482
# 18     17158
# 19         0
# Name: Sale Price, dtype: object
